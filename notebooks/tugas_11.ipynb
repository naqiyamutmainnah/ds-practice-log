# %% [markdown]
# <h2>Soal 1: Pemahaman Component Matplotlib</h2>
#
# - Jelaskan apa itu Figure
# - Jelaskan apa itu Axis

# %% [markdown]
# - Figure adalah window atau page atau halaman dalam objek visual. kalau kita ngegambar di kertas, maka kertas tersebutlah yang di namakan figure.
# - Axis adalah suatu area di dalam figure dimana data akan di plot. Dalam Axes juga terdapat berbagai macam komponen lagi seperti x-axis, y-axis, dan lain sebagainya.

# %% [markdown]
# <h2>Soal 2: Membuat Component Figure dan Axis</h2>
#
# - Buatlah Figure dan Axis kosong tanpa Data
# - Plot data di bawah ini dengan 2 cara, yaitu dengan membuat figure dan axis secara explicit dan Implicit

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 20, 100)
y = np.cos(x/2)

# %%
# membuat Figure dan Axis dengan Data Kosong

# %%
#eksplisit
# membuat objek figure
fig = plt.figure()

# membuat objek axes
ax = fig.add_subplot()

# menampilkan objek visual
plt.show()

# %%
#implicit
plt.plot(x, y)
plt.show()

# %% [markdown]
# Exected Output:
#
# ![alt text](https://drive.google.com/uc?id=1mq8HMFwz5GlTH_SPAFnXZZ8KnBWBC9d3)

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=156xwVvDgShvIPBefimXg18zfFjz_SQ8X)

# %% [markdown]
# <h2>Soal 3: Memasukan multiple data ke dalam satu axis</h2>
#
# - Plot ketiga data berikut ke dalam satu axis, dan gunakan seaborn style
# - save data tersebut dengan nama file bebas (apa saja) dan tampilkan kembali gambar tersebut.

# %%
x = np.linspace(0, 20, 100)
y = np.cos(x/2)
y2 = np.sin(x)
y3 = np.sin(2*x)

# %%
fig, ax = plt.subplots()
ax.plot(x, y, color='green')
ax.plot(x, y2, color='blue')
ax.plot(x, y3, color='red')

plt.show()
plt.savefig('eg.png')

# %% [markdown]
# Expected Output:
#
# ![alt text](https://drive.google.com/uc?id=1EnJDnXuJ97NZ9EcKQWRaGCD7-LroZ-Gj)

# %% [markdown]
# <h2>Soal 4:</h2>
#
# Dengan menggunakan data di bawah ini, plot kan data tersebut kemudian custom sehingga memiliki result seperti yang di harapkan :
#
# note: warna terdiri dari warna Hijau, kuning, Biru, dan Merah

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
cos = np.cos(x)
cos3 = np.cos(x)*3
sin = np.sin(x-90)
sin2 = np.sin(x)*2

# %%
#membuat figure
#untuk mengubah ukuran figure, kita bisa menggunakan parameter fig_size
fig = plt.figure(figsize=(12,8))
#membuat axes
ax = fig.add_subplot()
ax.plot(x, cos, color='red', label='Cosx', linewidth=0.5)
ax.plot(x, cos3, color='green', label='3 Cosx', linestyle='dashed', linewidth=0.5)
ax.plot(x, sin, color='blue', label='sin(x-90)', marker=".", linestyle='dashed', markersize=0.5, linewidth=0.5)
ax.plot(x, sin2, color='#ffe280', label='2Sinx', marker='x', linestyle='dashed', markersize=3, linewidth=0.1)

#menambahkan judul ke axes
ax.set_title("Grafik Cos Sin")

#menambahkan label pada axis
ax.set_xlabel("X-Axis Label")
ax.set_ylabel("Y-Axis Label")

plt.legend(loc="center")

plt.show()

# %% [markdown]
# Expected Result:
#
# ![alt text](https://drive.google.com/uc?id=1XRcfWyiWLDmriw7s7U4fTn5Gs6s2qf5o)
